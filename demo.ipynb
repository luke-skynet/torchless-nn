# %% [markdown]
# ### CuPy Setup and imports

# %%
# !pip install cupy-cuda12x cutensor-cu12

# %%
import os
import numpy as np

os.environ['CUPY_TF32'] = "1"
os.environ['CUPY_ACCELERATORS'] = "cub,cutensor"

import cupy
from cupy.cuda import cublas

cublas_handle = cupy.cuda.Device().cublas_handle
cublas.setMathMode(cublas_handle, cublas.CUBLAS_TENSOR_OP_MATH)

import pickle

import seaborn as sns
import matplotlib.pyplot as plt

from activations import SiLU, SoftMax
from layers import TransformerBlock, LayerNorm, Convolution, Flatten, MaxPool, AveragePool, BatchNorm, Dense, Dropout
from network import Network, CrossEntropy
from transformer_adapters import VitProjector, VitMLPHead, GPTEmbedFront, GPTEmbedBack, GPTEmbeddingTable
from utils import Layer, Residual, init_random_tensor, augment_images

# %%
from keras.datasets.mnist import load_data

(x_train, y_train), (x_test, y_test) = load_data()

x_train = (x_train / 255).astype(np.float32)
x_test  = (x_test / 255).astype(np.float32)

x_train = x_train.reshape(-1, 1, 28, 28)
x_test  = x_test.reshape(-1, 1, 28, 28)

y_train = y_train.reshape(-1)
y_test  = y_test.reshape(-1)

print(x_train.shape, x_train.dtype, y_train.shape, y_train.dtype)
print(x_test.shape, x_test.dtype, y_test.shape, y_test.dtype)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 1, 28, 28) float32 (60000,) uint8
# (10000, 1, 28, 28) float32 (10000,) uint8

# %%
model = Network(
    [
        Convolution((1, 28, 28), 32, (3,3), padding = (1,1)),
        MaxPool(2,2),
        SiLU(),
        Dropout(0.25),

        Convolution((32, 14, 14), 64, (3,3), padding = (1,1)),
        MaxPool(2,2),
        SiLU(),
        Dropout(0.25),

        Flatten(),
        Dense(7*7*64, 128),
        SiLU(),
        Dropout(0.25),
        Dense(128, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test,
            epochs = 10,
            learning_rate = 0.003,
            weight_decay = 0.01,
            batch_size = 256)
# Out:
# 100%|██████████| 235/235 [00:08<00:00, 27.27it/s]
# epoch: 1 train loss: 0.17697985026041665 train accuracy: 0.94355
# 100%|██████████| 40/40 [00:00<00:00, 211.84it/s]
# epoch: 1 test loss: 0.05104490966796875 test accuracy: 0.9824
# 100%|██████████| 235/235 [00:03<00:00, 64.29it/s]
# epoch: 2 train loss: 0.05961553955078125 train accuracy: 0.9816333333333334
# 100%|██████████| 40/40 [00:00<00:00, 198.32it/s]
# epoch: 2 test loss: 0.03389866943359375 test accuracy: 0.988
# 100%|██████████| 235/235 [00:03<00:00, 64.97it/s]
# epoch: 3 train loss: 0.04507480875651042 train accuracy: 0.9858333333333333
# 100%|██████████| 40/40 [00:00<00:00, 215.86it/s]
# epoch: 3 test loss: 0.030302438354492187 test accuracy: 0.9892
# 100%|██████████| 235/235 [00:03<00:00, 65.59it/s]
# epoch: 4 train loss: 0.03696962076822917 train accuracy: 0.9879833333333333
# 100%|██████████| 40/40 [00:00<00:00, 185.32it/s]
# epoch: 4 test loss: 0.027148193359375 test accuracy: 0.9913
# ...

# %%
from keras.datasets.cifar10 import load_data

(x_train, y_train), (x_test, y_test) = load_data()

x_train = (x_train / 255).astype(np.float32)
x_test  = (x_test / 255).astype(np.float32)

x_train = x_train.transpose(0,3,1,2)
x_test  = x_test.transpose(0,3,1,2)

y_train = y_train.reshape(-1)
y_test  = y_test.reshape(-1)

print(x_train.shape, x_train.dtype, y_train.shape, y_train.dtype)
print(x_test.shape, x_test.dtype, y_test.shape, y_test.dtype)

# %%
def load_batch(batch_path):
    with open(batch_path, 'rb') as f:
        dct = pickle.load(f, encoding='latin1')
    data = dct['data']
    labels = np.array(dct['labels'])
    data = data.reshape(-1, 3, 32, 32)
    return data, labels


def load_cifar10(root = ""):
    x_train = []
    y_train = []

    for i in range(1, 6):
        data, labels = load_batch(os.path.join(root, f"data_batch_{i}"))
        x_train.append(data)
        y_train.append(labels)

    x_train = np.concatenate(x_train)
    y_train = np.concatenate(y_train)

    x_test, y_test = load_batch(os.path.join(root, "test_batch"))

    return x_train, y_train, x_test, y_test


x_train, y_train, x_test, y_test = load_cifar10(root = "/content/drive/MyDrive/datasets/cifar-10-batches-py")

x_train = (x_train / 255).astype(np.float32)
x_test  = (x_test / 255).astype(np.float32)

print(x_train.shape, x_train.dtype, y_train.shape, y_train.dtype)
print(x_test.shape, x_test.dtype, y_test.shape, y_test.dtype)
# Out:
# (50000, 3, 32, 32) float32 (50000,) int64
# (10000, 3, 32, 32) float32 (10000,) int64

# %%
# Modified DenseNet

def dense_layer(input_size, growth_rate, dropout_rate):
  return Residual(
      [
          BatchNorm(input_size[0]),
          SiLU(),
          Dropout(dropout_rate),
          Convolution(input_size, growth_rate, (3, 3), padding = (1, 1)),

      ],
      mode = "concat"

  )

def transition_block(input_size, out_channels, dropout_rate):
  return [
          BatchNorm(input_size[0]),
          SiLU(),
          Dropout(dropout_rate),
          Convolution(input_size, out_channels, (1,1)),
          AveragePool(2,2),
]

dropout_rate = 0.25
growth_rate = 16

model = Network(
    [
        Convolution((3,32,32), 32, (3,3), padding = (1,1)),

        dense_layer((32, 32,32), growth_rate, dropout_rate),
        dense_layer((48, 32,32), growth_rate, dropout_rate),
        dense_layer((64, 32,32), growth_rate, dropout_rate),
        dense_layer((80, 32,32), growth_rate, dropout_rate),
        dense_layer((96, 32,32), growth_rate, dropout_rate),
        dense_layer((112,32,32), growth_rate, dropout_rate),

    ] + transition_block((128,32,32), 64, dropout_rate) + [

        dense_layer((64, 16,16), growth_rate, dropout_rate),
        dense_layer((80, 16,16), growth_rate, dropout_rate),
        dense_layer((96, 16,16), growth_rate, dropout_rate),
        dense_layer((112,16,16), growth_rate, dropout_rate),
        dense_layer((128,16,16), growth_rate, dropout_rate),
        dense_layer((144,16,16), growth_rate, dropout_rate),

    ] + transition_block((160,16,16), 80, dropout_rate) + [

        dense_layer((80, 8,8), growth_rate, dropout_rate),
        dense_layer((96, 8,8), growth_rate, dropout_rate),
        dense_layer((112,8,8), growth_rate, dropout_rate),
        dense_layer((128,8,8), growth_rate, dropout_rate),
        dense_layer((144,8,8), growth_rate, dropout_rate),
        dense_layer((160,8,8), growth_rate, dropout_rate),

        AveragePool(8,8),
        Flatten(),
        Dense(176, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

# %%
model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test,
            augments=augment_images,
            epochs = 20,
            learning_rate = 0.001,
            batch_size = 256,
            weight_decay = 0.01)
# Out:
# 100%|██████████| 196/196 [01:06<00:00,  2.95it/s]
# epoch: 1 train loss: 1.6380859375 train accuracy: 0.38726
# 100%|██████████| 40/40 [00:02<00:00, 17.56it/s]
# epoch: 1 test loss: 1.46298359375 test accuracy: 0.4873
# 100%|██████████| 196/196 [01:04<00:00,  3.06it/s]
# epoch: 2 train loss: 1.29910515625 train accuracy: 0.52734
# 100%|██████████| 40/40 [00:02<00:00, 17.35it/s]
# epoch: 2 test loss: 1.44844228515625 test accuracy: 0.5395
# 100%|██████████| 196/196 [01:04<00:00,  3.06it/s]
# epoch: 3 train loss: 1.131106796875 train accuracy: 0.59288
# 100%|██████████| 40/40 [00:02<00:00, 17.52it/s]
# epoch: 3 test loss: 1.30619990234375 test accuracy: 0.5795
# 100%|██████████| 196/196 [01:04<00:00,  3.05it/s]
# epoch: 4 train loss: 1.032943515625 train accuracy: 0.63184
# 100%|██████████| 40/40 [00:02<00:00, 17.38it/s]
# epoch: 4 test loss: 1.08577138671875 test accuracy: 0.6357
# 100%|██████████| 196/196 [01:04<00:00,  3.05it/s]
# ...

# %%
embed_size = 256
num_heads = 4
num_registers = 15
attn_dropout_rate = 0.10
res_dropout_rate = 0.10

model = Network(
    [
        VitProjector((3, 32, 32), (2, 2), embed_size, num_registers = num_registers),

        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

        LayerNorm(embed_size),
        VitMLPHead(embed_size, 256),

        SiLU(),
        Dropout(dropout_rate),

        Dense(256, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

# %%
model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test,
            augments=augment_images,
            epochs = 20,
            learning_rate = 0.001,
            batch_size = 64,
            batches_per_step = 4,
            weight_decay = 0.01)
# Out:
# 100%|██████████| 782/782 [02:04<00:00,  6.28it/s]
# epoch: 1 train loss: 2.154961875 train accuracy: 0.17254
# 100%|██████████| 157/157 [00:05<00:00, 27.11it/s]
# epoch: 1 test loss: 2.0364341796875 test accuracy: 0.232
# 100%|██████████| 782/782 [02:03<00:00,  6.32it/s]
# epoch: 2 train loss: 1.87956890625 train accuracy: 0.26706
# 100%|██████████| 157/157 [00:05<00:00, 27.11it/s]
# epoch: 2 test loss: 1.73055 test accuracy: 0.3288
# 100%|██████████| 782/782 [02:03<00:00,  6.32it/s]
# epoch: 3 train loss: 1.75478828125 train accuracy: 0.31428
# 100%|██████████| 157/157 [00:05<00:00, 27.10it/s]
# epoch: 3 test loss: 1.6759333984375 test accuracy: 0.3571
# 100%|██████████| 782/782 [02:03<00:00,  6.31it/s]
# epoch: 4 train loss: 1.7002596875 train accuracy: 0.34012
# 100%|██████████| 157/157 [00:05<00:00, 27.09it/s]
# epoch: 4 test loss: 1.6918734375 test accuracy: 0.3548
# 100%|██████████| 782/782 [02:03<00:00,  6.31it/s]
# epoch: 5 train loss: 1.66233859375 train accuracy: 0.36516
# ...

# %%
# Adapted from Andrej Karpathy's GPT Tutorial: https://github.com/karpathy/ng-video-lecture

text = None
with open('lotr.txt') as handle:
    text = handle.read()

chars = sorted(list(set(text)))

vocab_size = len(chars) # 64 for shakespeare / 80 for lotr
embed_size = 256
num_heads = 4
context_length = 512


learning_rate = 0.0003
batch_size = 64
batches_per_step = 4
steps = 30000

attn_dropout_rate = 0.10
res_dropout_rate = 0.10
emb_dropout_rate = 0.10


# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

tokens = np.array(encode(text), dtype=np.uint8)
arr = []
for i in range(len(tokens) - context_length + 1):
  arr.append(tokens[i:i+context_length])

arr = np.array(arr, dtype=np.uint8)

data = arr[:-1]
labels = arr[1:]

shuffle = np.random.permutation(len(data))

data = data[shuffle]
labels = labels[shuffle]
print(data.shape, data.dtype, labels.shape, labels.dtype)
# Out:
# (3086891, 512) uint8 (3086891, 512) uint8

# %%
class GPT:
    def __init__(self):

        self.embedding_table = GPTEmbeddingTable(vocab_size, embed_size)
        self.model = Network(
            [
                GPTEmbedFront(self.embedding_table, context_length),
                Dropout(emb_dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

                LayerNorm(embed_size),
                GPTEmbedBack(self.embedding_table),
                SoftMax()
            ],
        )
        self.criterion = CrossEntropy(num_classes = vocab_size)


    def train(self):

      x_train = data[:steps*batch_size]
      y_train = labels[:steps*batch_size]

      x_test = data[steps*batch_size:steps*batch_size + 100 * batch_size]
      y_test = labels[steps*batch_size:steps*batch_size + 100 * batch_size]

      self.model.train(self.criterion, x_train, y_train,
                       test_data=x_test, test_labels=y_test,
                       epochs = 1,
                       learning_rate = learning_rate,
                       batch_size = batch_size,
                       batches_per_step = batches_per_step)

    def generate(self, length, seed = " "):

          print(seed, end = "")

          tokens = cupy.array(encode(seed), dtype = cupy.uint8).reshape((1, len(seed)))

          for i in range(length):

            tokens = tokens[:,max(0, len(tokens[0]) - context_length):]

            probs = self.model.predict(tokens)[0, -1]
            out = cupy.random.choice(cupy.arange(0, vocab_size, dtype = cupy.uint8), size = (1,1), p = probs)

            tokens = cupy.concatenate((tokens, out), axis = 1)

            print(itos[int(out[0,0].get())], end = "")

gpt = GPT()

# %%
gpt.model.predict(cupy.array(data[:batch_size]))
for layer in gpt.model.layers:
  print("Input Type:", layer.input.dtype, "Layer:", type(layer), "Output Type:", layer.output.dtype)
# Out:
# Input Type: uint8 Layer: <class 'transformer_adapters.GPTEmbedFront'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.Dropout'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# ...

# %%
gpt.train()
# Out:
# 100%|██████████| 30000/30000 [2:45:49<00:00,  3.02it/s]
# epoch: 1 train loss: 2.2016408854166665 train accuracy: 0.3727526387532552
# 100%|██████████| 100/100 [00:08<00:00, 12.14it/s]
# epoch: 1 test loss: 1.2890621948242187 test accuracy: 0.6039889526367187

# %%
gpt.model.set_eval(True)
gpt.model.layers[-1].temperature = 1.0
gpt.generate(2048, "Aragorn")
# Out:
# Aragorn the City of Mordor,
# in the Road cheast come over the others clash passed.
#  At lieness it as he hardly that voice, and he someon ber opened forth thought
# its a place. So they had been stood of disauted the king of little knew as there,
# even went their pale and that some began a relized by my ended). Acrosss, or
# hand, as also he ponded, they were sunling but a warning rowing that he look of would
# haved.
#  At least once. But while questionan his hurts at turned would were return too
# him. His hay could be seemed to help
# comfort: they hair of their fager, as he hand of the botttomm that left
# his from head in the cater right. But foole the far his own drew sensecaped of the
# tall. But the in the compas red. He happened the poorts of the ent food southward
# passed; but be another in the door after the Mark White Elves in march hobbbit
# stood his broken. He had been against Gollum in a nnough, and a for own and
# hands stones of Beregond.
# ...

# %%
# Visualize token dot product similarities
similarities = (gpt.embedding_table @ gpt.embedding_table.transpose()).get()


similarities /= np.linalg.trace(similarities)

for i in range(len(similarities)):
  similarities[i, i] = 0

sns.heatmap(similarities, cmap = "viridis")
plt.show()

# %%
path = "/content/drive/MyDrive/ai-models/"

# %%
def save_weights(model, path):

  lst = []

  for layer in model.layers:

    dct = {
        "name": type(layer).__name__,
        "parameters": []
    }

    for parameter in layer.parameters:
      dct["parameters"].append(parameter.get())
    lst.append(dct)

  with open(path, "wb") as handle:
    pickle.dump(lst, handle)


def load_weights(model, path):

  model._zero_grad()

  lst = []

  with open(path, "rb") as handle:
    lst = pickle.load(handle)

  for layer, dct in zip(model.layers, lst):
    for parameter, arr in zip(layer.parameters, dct["parameters"]):
      parameter *= 0
      parameter += cupy.array(arr, dtype = cupy.float32)

# %%
save_weights(gpt.model, path + "my_lotr_gpt_512.pkl")

# %%
load_weights(gpt.model, path + "my_lotr_gpt_1024.pkl")

# %% [markdown]
# ### Naive/Unoptimized Pytorch DenseNet Comparison

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchsummary
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
trainsform = transforms.Compose(
    [
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding = 4),
        transforms.RandomRotation(15),
        transforms.ToTensor()
    ]
)

testsform = transforms.Compose(
    [
        transforms.ToTensor()
    ])

batch_size = 256

trainset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/datasets', train=True,
                                        download=True, transform=trainsform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/datasets', train=False,
                                       download=True, transform=testsform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
class DenseLayer(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, growth_rate, 3, padding = 1),
        )


    def forward(self, x):
        return torch.concat((x, self.fn(x)), dim = 1)

class DenseBlock(nn.Module):
    def __init__(self, in_channels, growth_rate, num_layers):
        super().__init__()
        self.layers = nn.Sequential(*[
            DenseLayer(in_channels + (i * growth_rate), growth_rate) for i in range(num_layers)
        ])
    def forward(self, x):
        return self.layers(x)

class TransitionBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, out_channels, 1),
            nn.AvgPool2d(2,2)
        )
    def forward(self, x):
        return self.fn(x)


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding = 1),
            DenseBlock(32, 16, 6),
            TransitionBlock(128, 64),
            DenseBlock(64, 16, 6),
            TransitionBlock(160, 80),
            DenseBlock(80, 16, 6),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(176, 10),
        )

    def forward(self, x):
        return self.net(x)

net = Net()
net.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001)

# %%
for epoch in range(20):  # loop over the dataset multiple times

    net.train()
    running_loss = 0.0

    for i, data in tqdm(enumerate(trainloader, 0), total = len(trainloader)):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()

    print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / len(trainloader)}')


    net.eval()
    total = 0
    correct = 0

    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for i, data in tqdm(enumerate(testloader, 0), total = len(testloader)):

            images, labels = data
            images = images.to(device)
            labels = labels.to(device)

            # calculate outputs by running images through the network
            outputs = net(images)

            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f'Test Accuracy: {100 * correct // total} %')
# Out:
# 100%|██████████| 196/196 [00:24<00:00,  8.10it/s]
# [1,   196] loss: 1.6019062138333613
# 100%|██████████| 40/40 [00:01<00:00, 23.43it/s]
# Test Accuracy: 43 %
# 100%|██████████| 196/196 [00:24<00:00,  8.01it/s]
# [2,   196] loss: 1.283208345272103
# 100%|██████████| 40/40 [00:01<00:00, 23.06it/s]
# Test Accuracy: 55 %
# 100%|██████████| 196/196 [00:24<00:00,  8.08it/s]
# [3,   196] loss: 1.1199241715426347
# 100%|██████████| 40/40 [00:01<00:00, 23.50it/s]
# Test Accuracy: 58 %
# 100%|██████████| 196/196 [00:24<00:00,  8.08it/s]
# [4,   196] loss: 1.028261511605613
# 100%|██████████| 40/40 [00:01<00:00, 23.45it/s]
# Test Accuracy: 63 %
# 100%|██████████| 196/196 [00:24<00:00,  8.14it/s]
# [5,   196] loss: 0.9608131832614237
# 100%|██████████| 40/40 [00:01<00:00, 23.55it/s]
# Test Accuracy: 66 %
# 100%|██████████| 196/196 [00:24<00:00,  8.12it/s]
# [6,   196] loss: 0.9077457146985191
# 100%|██████████| 40/40 [00:01<00:00, 23.50it/s]
# Test Accuracy: 64 %
# ...

# %% [markdown]
# ### Optimized Pytorch DenseNet Comparison

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchsummary
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

torch.backends.fp32_precision = "tf32"
torch.backends.cudnn.benchmark = True
torch._logging.set_logs(graph_code=True)

# %%
trainsform = transforms.Compose(
    [
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding=4),
        transforms.RandomRotation(15),
        transforms.ToTensor()
    ]
)

testsform = transforms.Compose(
    [
        transforms.ToTensor()
    ])

batch_size = 256

trainset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/datasets', train=True,
                                        download=True, transform=trainsform)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=4,
                                          pin_memory=True)

testset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/datasets', train=False,
                                       download=True, transform=testsform)

testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=4,
                                         pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
class DenseLayer(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, growth_rate, 3, padding = 1, bias = False),
        )


    def forward(self, x):
        return torch.concat((x, self.fn(x)), dim = 1)

class DenseBlock(nn.Module):
    def __init__(self, in_channels, growth_rate, num_layers):
        super().__init__()
        self.layers = nn.Sequential(*[
            DenseLayer(in_channels + (i * growth_rate), growth_rate) for i in range(num_layers)
        ])
    def forward(self, x):
        return self.layers(x)

class TransitionBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, out_channels, 1, bias = False),
            nn.AvgPool2d(2,2)
        )
    def forward(self, x):
        return self.fn(x)


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding = 1, bias = False),
            DenseBlock(32, 16, 6),
            TransitionBlock(128, 64),
            DenseBlock(64, 16, 6),
            TransitionBlock(160, 80),
            DenseBlock(80, 16, 6),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(176, 10),
        )

    def forward(self, x):
        return self.net(x)

net = Net()
net.to(device, memory_format=torch.channels_last)
torch.compile(net)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001)

# %%
for epoch in range(20):  # loop over the dataset multiple times

    net.train()
    running_loss = torch.tensor(0.0, device = device)

    for i, data in tqdm(enumerate(trainloader, 0), total = len(trainloader)):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        inputs = inputs.to(device, memory_format = torch.channels_last)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad(set_to_none=True)

        # forward + backward + optimize
        with torch.autocast(device_type = "cuda", dtype = torch.bfloat16):
            outputs = net(inputs)
            loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.detach()

    print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss.item() / len(trainloader)}')


    net.eval()
    total = 0
    correct = torch.tensor(0, device = device)

    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for i, data in tqdm(enumerate(testloader, 0), total = len(testloader)):

            images, labels = data
            images = images.to(device, memory_format = torch.channels_last)
            labels = labels.to(device)

            # calculate outputs by running images through the network
            with torch.autocast(device_type = "cuda", dtype = torch.bfloat16):
                outputs = net(images)

            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs, 1)

            total += labels.size(0)
            correct += (predicted == labels).sum()

    print(f'Test Accuracy: {100 * correct.item() // total} %')
# Out:
# 100%|██████████| 196/196 [01:23<00:00,  2.36it/s]
# [1,   196] loss: 1.650549285265864
# 100%|██████████| 40/40 [00:12<00:00,  3.19it/s]
# Test Accuracy: 44 %
# 100%|██████████| 196/196 [00:04<00:00, 39.48it/s]
# [2,   196] loss: 1.3155866350446428
# 100%|██████████| 40/40 [00:00<00:00, 85.73it/s]
# Test Accuracy: 55 %
# 100%|██████████| 196/196 [00:04<00:00, 41.97it/s]
# [3,   196] loss: 1.1287716456821986
# 100%|██████████| 40/40 [00:00<00:00, 82.79it/s]
# Test Accuracy: 60 %
# 100%|██████████| 196/196 [00:04<00:00, 40.51it/s]
# [4,   196] loss: 1.0292398880939095
# 100%|██████████| 40/40 [00:00<00:00, 72.52it/s]
# Test Accuracy: 61 %
# 100%|██████████| 196/196 [00:05<00:00, 38.53it/s]
# [5,   196] loss: 0.956735338483538
# 100%|██████████| 40/40 [00:00<00:00, 79.85it/s]
# Test Accuracy: 67 %
# 100%|██████████| 196/196 [00:04<00:00, 40.18it/s]
# [6,   196] loss: 0.8982589877381617
# 100%|██████████| 40/40 [00:00<00:00, 74.81it/s]
# Test Accuracy: 69 %
# ...
