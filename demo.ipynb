# %%
import os

os.environ['CUPY_TF32'] = "1"
os.environ['CUPY_ACCELERATORS'] = "cub,cutensor"

import numpy as np

from backend import xp, to_numpy

import pickle

import seaborn as sns
import matplotlib.pyplot as plt

from activations import SiLU, SoftMax
from layers import TransformerBlock, LayerNorm, Convolution, Flatten, MaxPool, AveragePool, BatchNorm, Dense, Dropout
from network import Network, CrossEntropy
from transformer_adapters import VitProjector, VitMLPHead, GPTEmbeddingTable, GPTEmbedFront, GPTEmbedBack
from backend import init_random_tensor
from utils import Layer, Residual, augment_images

if xp is not np:
    cublas = xp.cuda.cublas
    cublas_handle = xp.cuda.Device().cublas_handle
    cublas.setMathMode(cublas_handle, cublas.CUBLAS_TENSOR_OP_MATH)

# %%
def load_batch(batch_path):
    with open(batch_path, 'rb') as f:
        dct = pickle.load(f, encoding='latin1')
    data = dct['data']
    labels = np.array(dct['labels'])
    data = data.reshape(-1, 3, 32, 32)
    return data, labels


def load_cifar10(root = ""):
    x_train = []
    y_train = []

    for i in range(1, 6):
        data, labels = load_batch(os.path.join(root, f"data_batch_{i}"))
        x_train.append(data)
        y_train.append(labels)

    x_train = np.concatenate(x_train)
    y_train = np.concatenate(y_train)

    x_test, y_test = load_batch(os.path.join(root, "test_batch"))

    return x_train, y_train, x_test, y_test


x_train, y_train, x_test, y_test = load_cifar10(root = "dataset/cifar-10-batches-py")

x_train = (x_train / 255).astype(np.float32)
x_test  = (x_test / 255).astype(np.float32)

print(x_train.shape, x_train.dtype, y_train.shape, y_train.dtype)
print(x_test.shape, x_test.dtype, y_test.shape, y_test.dtype)
# Out:
# (50000, 3, 32, 32) float32 (50000,) int64
# (10000, 3, 32, 32) float32 (10000,) int64

# %%
# Modified DenseNet

def dense_layer(input_size, growth_rate, dropout_rate):
  return Residual(
      [
          BatchNorm(input_size[0]),
          SiLU(),
          Dropout(dropout_rate),
          Convolution(input_size, growth_rate, (3, 3), padding = (1, 1)),

      ],
      mode = "concat"

  )

def transition_block(input_size, out_channels, dropout_rate):
  return [
          BatchNorm(input_size[0]),
          SiLU(),
          Dropout(dropout_rate),
          Convolution(input_size, out_channels, (1,1)),
          AveragePool(2,2),
]

dropout_rate = 0.25
growth_rate = 16

model = Network(
    [
        Convolution((3,32,32), 32, (3,3), padding = (1,1)),

        dense_layer((32, 32,32), growth_rate, dropout_rate),
        dense_layer((48, 32,32), growth_rate, dropout_rate),
        dense_layer((64, 32,32), growth_rate, dropout_rate),
        dense_layer((80, 32,32), growth_rate, dropout_rate),
        dense_layer((96, 32,32), growth_rate, dropout_rate),
        dense_layer((112,32,32), growth_rate, dropout_rate),

    ] + transition_block((128,32,32), 64, dropout_rate) + [

        dense_layer((64, 16,16), growth_rate, dropout_rate),
        dense_layer((80, 16,16), growth_rate, dropout_rate),
        dense_layer((96, 16,16), growth_rate, dropout_rate),
        dense_layer((112,16,16), growth_rate, dropout_rate),
        dense_layer((128,16,16), growth_rate, dropout_rate),
        dense_layer((144,16,16), growth_rate, dropout_rate),

    ] + transition_block((160,16,16), 80, dropout_rate) + [

        dense_layer((80, 8,8), growth_rate, dropout_rate),
        dense_layer((96, 8,8), growth_rate, dropout_rate),
        dense_layer((112,8,8), growth_rate, dropout_rate),
        dense_layer((128,8,8), growth_rate, dropout_rate),
        dense_layer((144,8,8), growth_rate, dropout_rate),
        dense_layer((160,8,8), growth_rate, dropout_rate),

        AveragePool(8,8),
        Flatten(),
        Dense(176, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

# %%
model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test,
            augments=augment_images,
            epochs = 20,
            learning_rate = 0.001, 
            batch_size = 512,
            batches_per_step = 1,
            weight_decay = 0.01)
# Out:
# 100%|██████████| 98/98 [01:01<00:00,  1.61it/s]
# epoch: 1 train loss: 1.8196522 train accuracy: 0.31348
# 100%|██████████| 20/20 [00:01<00:00, 12.77it/s]
# epoch: 1 test loss: 1.7758181 test accuracy: 0.3677
# 100%|██████████| 98/98 [01:00<00:00,  1.62it/s]
# epoch: 2 train loss: 1.6095953 train accuracy: 0.39692
# 100%|██████████| 20/20 [00:01<00:00, 12.84it/s]
# epoch: 2 test loss: 1.7327862 test accuracy: 0.3997
# 100%|██████████| 98/98 [01:00<00:00,  1.62it/s]
# epoch: 3 train loss: 1.4486787 train accuracy: 0.46538
# 100%|██████████| 20/20 [00:01<00:00, 12.80it/s]
# epoch: 3 test loss: 1.6392945 test accuracy: 0.4838
# 100%|██████████| 98/98 [01:00<00:00,  1.62it/s]
# epoch: 4 train loss: 1.311195 train accuracy: 0.51972
# 100%|██████████| 20/20 [00:01<00:00, 12.81it/s]
# epoch: 4 test loss: 1.7010744 test accuracy: 0.4824
# 100%|██████████| 98/98 [01:00<00:00,  1.62it/s]
# epoch: 5 train loss: 1.2142414 train accuracy: 0.55644
# 100%|██████████| 20/20 [00:01<00:00, 12.82it/s]
# ...

# %%
embed_size = 384
num_heads = 6
num_registers = 15
dropout_rate = 0.20

model = Network(
    [
        VitProjector((3, 32, 32), (4, 4), embed_size, num_registers = num_registers),

        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),

        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),

        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, glu = True, hidden_dropout_rate = dropout_rate),

        LayerNorm(embed_size),
        VitMLPHead(embed_size, 128),

        SiLU(),
        Dropout(dropout_rate),

        Dense(128, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

# %%
model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test, 
            augments=augment_images, 
            epochs = 20,
            learning_rate = 0.001,
            batch_size = 512,
            batches_per_step = 1,
            weight_decay = 0.01)
# Out:
# 100%|██████████| 98/98 [00:44<00:00,  2.20it/s]
# epoch: 1 train loss: 2.3017442 train accuracy: 0.14152
# 100%|██████████| 20/20 [00:02<00:00,  9.24it/s]
# epoch: 1 test loss: 2.2688115 test accuracy: 0.1795
# 100%|██████████| 98/98 [00:43<00:00,  2.26it/s]
# epoch: 2 train loss: 2.1373262 train accuracy: 0.21154
# 100%|██████████| 20/20 [00:02<00:00,  9.24it/s]
# epoch: 2 test loss: 2.0585299 test accuracy: 0.2142
# 100%|██████████| 98/98 [00:43<00:00,  2.26it/s]
# epoch: 3 train loss: 2.0524893 train accuracy: 0.24796
# 100%|██████████| 20/20 [00:02<00:00,  9.24it/s]
# epoch: 3 test loss: 1.9348133 test accuracy: 0.2858
# 100%|██████████| 98/98 [00:43<00:00,  2.26it/s]
# epoch: 4 train loss: 1.9764413 train accuracy: 0.27688
# 100%|██████████| 20/20 [00:02<00:00,  9.23it/s]
# epoch: 4 test loss: 1.8677291 test accuracy: 0.3226
# 100%|██████████| 98/98 [00:43<00:00,  2.26it/s]
# epoch: 5 train loss: 1.9054883 train accuracy: 0.30904
# ...

# %%
# Adapted from Andrej Karpathy's GPT Tutorial: https://github.com/karpathy/ng-video-lecture

text = None
with open('datasets/lotr.txt') as handle:
    text = handle.read()

chars = sorted(list(set(text)))

vocab_size = len(chars) # 64 for shakespeare / 80 for lotr
embed_size = 384
num_heads = 6
context_length = 1024


learning_rate = 0.0003
batch_size = 16
steps = 30000
dropout_rate = 0.20


# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

tokens = np.array(encode(text), dtype=np.uint8)
arr = []
for i in range(len(tokens) - context_length + 1):
  arr.append(tokens[i:i+context_length])

arr = np.array(arr, dtype=np.uint8)

data = arr[:-1]
labels = arr[1:]

shuffle = np.random.permutation(len(data))

data = data[shuffle]
labels = labels[shuffle]
print(data.shape, data.dtype, labels.shape, labels.dtype)
# Out:
# (3086379, 1024) uint8 (3086379, 1024) uint8

# %%
class GPT:
    def __init__(self):

        self.embedding_table = GPTEmbeddingTable(vocab_size, embed_size)
        self.model = Network(
            [
                GPTEmbedFront(self.embedding_table, context_length),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, glu = True, decoder = True, hidden_dropout_rate=dropout_rate),

                LayerNorm(embed_size),
                GPTEmbedBack(self.embedding_table),
                SoftMax()
            ],
        )
        self.criterion = CrossEntropy(num_classes = vocab_size)


    def train(self):

      x_train = data[:steps*batch_size]
      y_train = labels[:steps*batch_size]

      x_test = data[steps*batch_size:steps*batch_size + 100 * batch_size]
      y_test = labels[steps*batch_size:steps*batch_size + 100 * batch_size]

      self.model.train(self.criterion, x_train, y_train,
                       test_data=x_test, test_labels=y_test,
                       epochs = 1, 
                       learning_rate = learning_rate,
                       batch_size = batch_size)

    def generate(self, length, seed = " "):

          print(seed, end = "")

          tokens = xp.array(encode(seed), dtype = xp.uint8).reshape((1, len(seed)))

          for i in range(length):

            tokens = tokens[:,max(0, len(tokens[0]) - context_length):]

            probs = self.model.predict(tokens)[0, -1]
            out = xp.random.choice(xp.arange(0, vocab_size, dtype = xp.uint8), size = (1,1), p = probs)

            tokens = xp.concatenate((tokens, out), axis = 1)

            print(itos[int(out[0,0])], end = "")

gpt = GPT()

# %%
gpt.model.predict(data[:batch_size])
for layer in gpt.model.layers:
  print("Input Type:", layer.input.dtype, "Layer:", type(layer), "Output Type:", layer.output.dtype)
# Out:
# Input Type: uint8 Layer: <class 'transformer_adapters.GPTEmbedFront'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# ...

# %%
gpt.train()
# Out:
# 100%|██████████| 30000/30000 [2:24:47<00:00,  3.45it/s]
# epoch: 1 train loss: 1.4420376302083333 train accuracy: 0.5834500569661458
# 100%|██████████| 100/100 [00:09<00:00, 10.56it/s]
# epoch: 1 test loss: 0.8666481781005859 test accuracy: 0.7214849853515625

# %%
gpt.model.set_eval(True)
gpt.model.layers[-1].temperature = 0.5
gpt.generate(2048, "Aragorn")
# Out:
# Aragorn and
# all the same her shall be accursed him again.
#  The dark was shall be before long ago. The sun was now gleaming voice
# shadow of the hill path from the northern borders of the Citadel clear
# voices. The forest were heavy feet and fear. The clapped from the hill
# crowned and shadows and heavy as the shadows of the River lay behind the
# wood.
#  The hobbits fell on the edge of the wall of the River came a great
# beyond the shadows of the Citadel called and set for a moment about them.
# The sun was riding down into a little river -bank, and a round the hearth
# like fire in the hollow hall, and a small shallow came near the end of
# dawn
# rain road and hall of the Captains of the West.
#  Legolas and Gimli went up and down against the walls of the West were
# horses of the West and came to the fences of the North. The Dwarves and
# Aragorn and the caverns of the deep cloven flowers of the East. The
# ...

# %%
# Visualize token dot product similarities
similarities = to_numpy(gpt.embedding_table.table @ gpt.embedding_table.table.transpose())


similarities /= np.linalg.trace(similarities)

for i in range(len(similarities)):
  similarities[i, i] = 0

sns.heatmap(similarities, cmap = "viridis")
plt.show()

# %%
path = "/content/drive/MyDrive/ai-models/"

# %%
def save_weights(model, path):

  lst = []

  for layer in model.layers:

    dct = {
        "name": type(layer).__name__,
        "parameters": []
    }

    for parameter in layer.parameters:
      dct["parameters"].append(to_numpy(parameter))
    lst.append(dct)

  with open(path, "wb") as handle:
    pickle.dump(lst, handle)


def load_weights(model, path):

  model._zero_grad()

  lst = []

  with open(path, "rb") as handle:
    lst = pickle.load(handle)

  for layer, dct in zip(model.layers, lst):
    for parameter, arr in zip(layer.parameters, dct["parameters"]):
      parameter *= 0
      parameter += xp.array(arr, dtype = xp.float32)

# %%
save_weights(gpt.model, path + "my_lotr_gpt_1024.pkl")

# %%
load_weights(gpt.model, path + "my_lotr_gpt_1024.pkl")
