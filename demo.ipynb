# %% [markdown]
# ### CuPy Setup and imports

# %%
# !pip install cupy-cuda12x cutensor-cu12
# Out:
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.13/dist-packages (14.0.1)
# Requirement already satisfied: cutensor-cu12 in /usr/local/lib/python3.13/dist-packages (2.8.0)
# Requirement already satisfied: numpy<2.6,>=2.0 in /usr/local/lib/python3.13/dist-packages (from cupy-cuda12x) (2.1.3)
# Requirement already satisfied: cuda-pathfinder==1.*,>=1.3.3 in /usr/local/lib/python3.13/dist-packages (from cupy-cuda12x) (1.8.0)

# %%
import os
import pickle

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from backend import xp, FLOAT_TYPE, init_random_tensor, init_zeros_tensor
from activations import SiLU, SoftMax
from layers import TransformerBlock, LayerNorm, Convolution, Flatten, MaxPool, AveragePool, BatchNorm, Dense, Dropout
from network import Network, CrossEntropy
from transformer_adapters import VitProjector, VitMLPHead, GPTEmbedFront, GPTEmbedBack, GPTEmbeddingTable
from utils import Layer, Residual, augment_images

# %%
from keras.datasets.mnist import load_data

(x_train, y_train), (x_test, y_test) = load_data()

x_train = (x_train / 255).astype(np.float32)
x_test  = (x_test / 255).astype(np.float32)

x_train = x_train.reshape(-1, 1, 28, 28)
x_test  = x_test.reshape(-1, 1, 28, 28)

y_train = y_train.reshape(-1)
y_test  = y_test.reshape(-1)

print(x_train.shape, x_train.dtype, y_train.shape, y_train.dtype)
print(x_test.shape, x_test.dtype, y_test.shape, y_test.dtype)
# Out:
# (60000, 1, 28, 28) float32 (60000,) uint8
# (10000, 1, 28, 28) float32 (10000,) uint8

# %%
model = Network(
    [
        Convolution((1, 28, 28), 32, (3,3), padding = (1,1)),
        MaxPool(2,2),
        SiLU(),
        Dropout(0.25),

        Convolution((32, 14, 14), 64, (3,3), padding = (1,1)),
        MaxPool(2,2),
        SiLU(),
        Dropout(0.25),

        Flatten(),
        Dense(7*7*64, 128),
        SiLU(),
        Dropout(0.25),
        Dense(128, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test,
            epochs = 10,
            learning_rate = 0.003,
            weight_decay = 0.01,
            batch_size = 256)
# Out:
# 100%|██████████| 235/235 [00:03<00:00, 72.10it/s]
# epoch: 1 train loss: 0.18161988932291667 train accuracy: 0.94215
# 100%|██████████| 40/40 [00:00<00:00, 230.99it/s]
# epoch: 1 test loss: 0.04711489562988281 test accuracy: 0.9842
# 100%|██████████| 235/235 [00:03<00:00, 73.63it/s]
# epoch: 2 train loss: 0.0589340576171875 train accuracy: 0.9818166666666667
# 100%|██████████| 40/40 [00:00<00:00, 241.60it/s]
# epoch: 2 test loss: 0.030572125244140626 test accuracy: 0.989
# 100%|██████████| 235/235 [00:03<00:00, 75.81it/s]
# epoch: 3 train loss: 0.046360624186197914 train accuracy: 0.9852666666666666
# 100%|██████████| 40/40 [00:00<00:00, 241.23it/s]
# epoch: 3 test loss: 0.02895860595703125 test accuracy: 0.9902
# 100%|██████████| 235/235 [00:03<00:00, 75.16it/s]
# epoch: 4 train loss: 0.03694117431640625 train accuracy: 0.9878833333333333
# 100%|██████████| 40/40 [00:00<00:00, 239.74it/s]
# epoch: 4 test loss: 0.02811826171875 test accuracy: 0.9916
# 100%|██████████| 235/235 [00:03<00:00, 74.68it/s]
# epoch: 5 train loss: 0.031885367838541664 train accuracy: 0.9893666666666666
# 100%|██████████| 40/40 [00:00<00:00, 238.65it/s]
# epoch: 5 test loss: 0.025105397033691405 test accuracy: 0.9921
# 100%|██████████| 235/235 [00:03<00:00, 73.31it/s]
# epoch: 6 train loss: 0.02669516398111979 train accuracy: 0.9914
# 100%|██████████| 40/40 [00:00<00:00, 235.06it/s]
# epoch: 6 test loss: 0.030684097290039063 test accuracy: 0.9907
# 100%|██████████| 235/235 [00:03<00:00, 73.97it/s]
# epoch: 7 train loss: 0.029555745442708333 train accuracy: 0.9900833333333333
# 100%|██████████| 40/40 [00:00<00:00, 235.52it/s]
# epoch: 7 test loss: 0.027743222045898436 test accuracy: 0.9915
# 100%|██████████| 235/235 [00:03<00:00, 74.17it/s]
# epoch: 8 train loss: 0.029149717203776043 train accuracy: 0.9903333333333333
# 100%|██████████| 40/40 [00:00<00:00, 236.03it/s]
# epoch: 8 test loss: 0.02654375 test accuracy: 0.9917
# 100%|██████████| 235/235 [00:03<00:00, 74.27it/s]
# epoch: 9 train loss: 0.022789080810546876 train accuracy: 0.9923833333333333
# 100%|██████████| 40/40 [00:00<00:00, 235.83it/s]
# epoch: 9 test loss: 0.029806390380859374 test accuracy: 0.9916
# 100%|██████████| 235/235 [00:03<00:00, 74.14it/s]
# epoch: 10 train loss: 0.024839461263020834 train accuracy: 0.9921666666666666
# 100%|██████████| 40/40 [00:00<00:00, 237.98it/s]
# epoch: 10 test loss: 0.029041058349609374 test accuracy: 0.9915

# %%
def load_batch(batch_path):
    with open(batch_path, 'rb') as f:
        dct = pickle.load(f, encoding='latin1')
    data = dct['data']
    labels = np.array(dct['labels'])
    data = data.reshape(-1, 3, 32, 32)
    return data, labels


def load_cifar10(root = ""):
    x_train = []
    y_train = []

    for i in range(1, 6):
        data, labels = load_batch(os.path.join(root, f"data_batch_{i}"))
        x_train.append(data)
        y_train.append(labels)

    x_train = np.concatenate(x_train)
    y_train = np.concatenate(y_train)

    x_test, y_test = load_batch(os.path.join(root, "test_batch"))

    return x_train, y_train, x_test, y_test


x_train, y_train, x_test, y_test = load_cifar10(root = "/content/drive/MyDrive/datasets/cifar-10-batches-py")

x_train = (x_train / 255).astype(np.float32)
x_test  = (x_test / 255).astype(np.float32)

print(x_train.shape, x_train.dtype, y_train.shape, y_train.dtype)
print(x_test.shape, x_test.dtype, y_test.shape, y_test.dtype)
# Out:
# (50000, 3, 32, 32) float32 (50000,) int64
# (10000, 3, 32, 32) float32 (10000,) int64

# %%
# Modified DenseNet

def dense_layer(input_size, growth_rate, dropout_rate):
  return Residual(
      [
          BatchNorm(input_size[0]),
          SiLU(),
          Dropout(dropout_rate),
          Convolution(input_size, growth_rate, (3, 3), padding = (1, 1)),

      ],
      mode = "concat"

  )

def transition_block(input_size, out_channels, dropout_rate):
  return [
          BatchNorm(input_size[0]),
          SiLU(),
          Dropout(dropout_rate),
          Convolution(input_size, out_channels, (1,1)),
          AveragePool(2,2),
]

dropout_rate = 0.25
growth_rate = 16

model = Network(
    [
        Convolution((3,32,32), 32, (3,3), padding = (1,1)),

        dense_layer((32, 32,32), growth_rate, dropout_rate),
        dense_layer((48, 32,32), growth_rate, dropout_rate),
        dense_layer((64, 32,32), growth_rate, dropout_rate),
        dense_layer((80, 32,32), growth_rate, dropout_rate),
        dense_layer((96, 32,32), growth_rate, dropout_rate),
        dense_layer((112,32,32), growth_rate, dropout_rate),

    ] + transition_block((128,32,32), 64, dropout_rate) + [

        dense_layer((64, 16,16), growth_rate, dropout_rate),
        dense_layer((80, 16,16), growth_rate, dropout_rate),
        dense_layer((96, 16,16), growth_rate, dropout_rate),
        dense_layer((112,16,16), growth_rate, dropout_rate),
        dense_layer((128,16,16), growth_rate, dropout_rate),
        dense_layer((144,16,16), growth_rate, dropout_rate),

    ] + transition_block((160,16,16), 80, dropout_rate) + [

        dense_layer((80, 8,8), growth_rate, dropout_rate),
        dense_layer((96, 8,8), growth_rate, dropout_rate),
        dense_layer((112,8,8), growth_rate, dropout_rate),
        dense_layer((128,8,8), growth_rate, dropout_rate),
        dense_layer((144,8,8), growth_rate, dropout_rate),
        dense_layer((160,8,8), growth_rate, dropout_rate),

        AveragePool(8,8),
        Flatten(),
        Dense(176, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

# %%
model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test,
            augments=augment_images,
            epochs = 20,
            learning_rate = 0.001,
            batch_size = 256,
            weight_decay = 0.01)
# Out:
# 100%|██████████| 196/196 [01:02<00:00,  3.14it/s]
# epoch: 1 train loss: 1.61660078125 train accuracy: 0.39576
# 100%|██████████| 40/40 [00:02<00:00, 18.14it/s]
# epoch: 1 test loss: 1.6528955078125 test accuracy: 0.4478
# 100%|██████████| 196/196 [01:02<00:00,  3.11it/s]
# epoch: 2 train loss: 1.30334921875 train accuracy: 0.52518
# 100%|██████████| 40/40 [00:02<00:00, 18.27it/s]
# epoch: 2 test loss: 1.3759712890625 test accuracy: 0.5267
# 100%|██████████| 196/196 [01:02<00:00,  3.13it/s]
# epoch: 3 train loss: 1.14363109375 train accuracy: 0.58948
# 100%|██████████| 40/40 [00:02<00:00, 18.24it/s]
# epoch: 3 test loss: 1.12586748046875 test accuracy: 0.6185
# 100%|██████████| 196/196 [01:02<00:00,  3.13it/s]
# epoch: 4 train loss: 1.037545625 train accuracy: 0.62898
# 100%|██████████| 40/40 [00:02<00:00, 18.20it/s]
# epoch: 4 test loss: 1.0102515625 test accuracy: 0.6522
# 100%|██████████| 196/196 [01:02<00:00,  3.13it/s]
# 100%|██████████| 196/196 [01:02<00:00,  3.14it/s]
# epoch: 17 train loss: 0.587040703125 train accuracy: 0.79368
# 100%|██████████| 40/40 [00:02<00:00, 18.29it/s]
# epoch: 17 test loss: 0.654711474609375 test accuracy: 0.7973
# 100%|██████████| 196/196 [01:02<00:00,  3.13it/s]
# epoch: 18 train loss: 0.5839423046875 train accuracy: 0.79724
# 100%|██████████| 40/40 [00:02<00:00, 18.31it/s]
# epoch: 18 test loss: 0.612211572265625 test accuracy: 0.8036
# 100%|██████████| 196/196 [01:02<00:00,  3.13it/s]
# epoch: 19 train loss: 0.5682244140625 train accuracy: 0.80136
# 100%|██████████| 40/40 [00:02<00:00, 18.36it/s]
# epoch: 19 test loss: 0.691861962890625 test accuracy: 0.7883
# 100%|██████████| 196/196 [01:02<00:00,  3.13it/s]
# epoch: 20 train loss: 0.557676015625 train accuracy: 0.8038
# 100%|██████████| 40/40 [00:02<00:00, 18.43it/s]
# epoch: 20 test loss: 0.57767802734375 test accuracy: 0.8122

# %%
embed_size = 256
num_heads = 4
num_registers = 4
attn_dropout_rate = 0.10
res_dropout_rate = 0.10

model = Network(
    [
        VitProjector((3, 32, 32), (2, 2), embed_size, num_registers = num_registers),

        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
        TransformerBlock(embed_size, 0, num_heads, SiLU, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

        LayerNorm(embed_size),
        VitMLPHead(embed_size, 256),

        SiLU(),
        Dropout(res_dropout_rate),

        Dense(256, 10),
        SoftMax()
    ]
)

criterion = CrossEntropy(10)

# %%
model.train(criterion, x_train, y_train,
            test_data=x_test, test_labels=y_test,
            augments=augment_images,
            epochs = 5,
            learning_rate = 0.001,
            batch_size = 64,
            batches_per_step = 4,
            weight_decay = 0.01)
# Out:
# 100%|██████████| 782/782 [02:03<00:00,  6.32it/s]
# epoch: 1 train loss: 2.11101359375 train accuracy: 0.18494
# 100%|██████████| 157/157 [00:05<00:00, 26.41it/s]
# epoch: 1 test loss: 1.8696935546875 test accuracy: 0.2555
# 100%|██████████| 782/782 [02:03<00:00,  6.35it/s]
# epoch: 2 train loss: 1.84580359375 train accuracy: 0.2693
# 100%|██████████| 157/157 [00:05<00:00, 26.41it/s]
# epoch: 2 test loss: 1.77524609375 test accuracy: 0.2876
# 100%|██████████| 782/782 [02:03<00:00,  6.35it/s]
# epoch: 3 train loss: 1.7621371875 train accuracy: 0.30786
# 100%|██████████| 157/157 [00:05<00:00, 26.41it/s]
# epoch: 3 test loss: 1.6864783203125 test accuracy: 0.3396
# 100%|██████████| 782/782 [02:03<00:00,  6.34it/s]
# epoch: 4 train loss: 1.681324375 train accuracy: 0.35598
# 100%|██████████| 157/157 [00:05<00:00, 26.38it/s]
# epoch: 4 test loss: 1.5870826171875 test accuracy: 0.3958
# 100%|██████████| 782/782 [02:03<00:00,  6.34it/s]
# epoch: 5 train loss: 1.6054128125 train accuracy: 0.39832
# 100%|██████████| 157/157 [00:05<00:00, 26.36it/s]
# epoch: 5 test loss: 1.52695546875 test accuracy: 0.4246

# %%
# Adapted from Andrej Karpathy's GPT Tutorial: https://github.com/karpathy/ng-video-lecture

text = None
with open('lotr.txt') as handle:
    text = handle.read()

chars = sorted(list(set(text)))

vocab_size = len(chars) # 64 for shakespeare / 80 for lotr
embed_size = 256
num_heads = 4
context_length = 512


learning_rate = 0.0003
batch_size = 64
batches_per_step = 4
steps = 30000

attn_dropout_rate = 0.10
res_dropout_rate = 0.10
emb_dropout_rate = 0.10


# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

tokens = np.array(encode(text), dtype=np.uint8)
arr = []
for i in range(len(tokens) - context_length + 1):
  arr.append(tokens[i:i+context_length])

arr = np.array(arr, dtype=np.uint8)

data = arr[:-1]
labels = arr[1:]

shuffle = np.random.permutation(len(data))

data = data[shuffle]
labels = labels[shuffle]
print(data.shape, data.dtype, labels.shape, labels.dtype)
# Out:
# (3086891, 512) uint8 (3086891, 512) uint8

# %%
class GPT:
    def __init__(self):

        self.embedding_table = GPTEmbeddingTable(vocab_size, embed_size)
        self.model = Network(
            [
                GPTEmbedFront(self.embedding_table, context_length),
                Dropout(emb_dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),
                TransformerBlock(embed_size, context_length, num_heads, SiLU, decoder = True, attn_dropout_rate = attn_dropout_rate, res_dropout_rate = res_dropout_rate),

                LayerNorm(embed_size),
                GPTEmbedBack(self.embedding_table),
                SoftMax()
            ],
        )
        self.criterion = CrossEntropy(num_classes = vocab_size)


    def train(self):

      x_train = data[:steps*batch_size]
      y_train = labels[:steps*batch_size]

      x_test = data[steps*batch_size:steps*batch_size + 100 * batch_size]
      y_test = labels[steps*batch_size:steps*batch_size + 100 * batch_size]

      self.model.train(self.criterion, x_train, y_train,
                       test_data=x_test, test_labels=y_test,
                       epochs = 1,
                       learning_rate = learning_rate,
                       batch_size = batch_size,
                       batches_per_step = batches_per_step)

    def generate(self, length, seed = " "):

          print(seed, end = "")

          tokens = xp.array(encode(seed), dtype = xp.uint8).reshape((1, len(seed)))

          for i in range(length):

            tokens = tokens[:,max(0, len(tokens[0]) - context_length):]

            probs = self.model.predict(tokens)[0, -1]
            out = xp.random.choice(xp.arange(0, vocab_size, dtype = xp.uint8), size = (1,1), p = probs)

            tokens = xp.concatenate((tokens, out), axis = 1)

            print(itos[int(out[0,0].get())], end = "")

gpt = GPT()

# %%
gpt.model.predict(xp.array(data[:batch_size]))
for layer in gpt.model.layers:
  print("Input Type:", layer.input.dtype, "Layer:", type(layer), "Output Type:", layer.output.dtype)
# Out:
# Input Type: uint8 Layer: <class 'transformer_adapters.GPTEmbedFront'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.Dropout'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.TransformerBlock'> Output Type: float32
# Input Type: float32 Layer: <class 'layers.LayerNorm'> Output Type: float32
# Input Type: float32 Layer: <class 'transformer_adapters.GPTEmbedBack'> Output Type: float32
# Input Type: float32 Layer: <class 'activations.SoftMax'> Output Type: float32

# %%
gpt.train()

# %%
gpt.model.set_eval(True)
gpt.model.layers[-1].temperature = 1.0
gpt.generate(2048, "Aragorn")
# Out:
# Aragorn the City of Mordor,
# in the Road cheast come over the others clash passed.
#  At lieness it as he hardly that voice, and he someon ber opened forth thought
# its a place. So they had been stood of disauted the king of little knew as there,
# even went their pale and that some began a relized by my ended). Acrosss, or
# hand, as also he ponded, they were sunling but a warning rowing that he look of would
# haved.
#  At least once. But while questionan his hurts at turned would were return too
# him. His hay could be seemed to help
# comfort: they hair of their fager, as he hand of the botttomm that left
# his from head in the cater right. But foole the far his own drew sensecaped of the
# tall. But the in the compas red. He happened the poorts of the ent food southward
# passed; but be another in the door after the Mark White Elves in march hobbbit
# stood his broken. He had been against Gollum in a nnough, and a for own and
# hands stones of Beregond.
#  'Ho! But he drawn as to go grist step, and is enough of Milb? What without
# so. Slitterly he hair?' he said. 'Are about too machfull to be course I have,
# but I've will go and without scresssing.'
#  'You hear. He darknesss how you shir? ' said Expection shall take, he far about
# be his going again.'
#  'Half,' said Gandalf pass the way away, but these a while lett and trouble
# far, what silver's face Pippin.
#
#  'Hold grasts sped and almost his cloak deep was with they would see
# that the Riders to be message. Still had silence their shall their high Faungorn
# Gondor: they said,
# as he stopped upon there a pace up seemed to a soort of the Edberohil, and they
# made filled it: Here's, sed he's said they splake home
# upon a mindd. Then the good spoke at high and speaking stirling, and
# their forward and head felt broke.
#
# 'Let Come was already and this came to lay delling again,' he said
# now guessts.
#  'The seemed to Frodo for a'roner, But I did, why have you shall done along.'
#
#  'Time have no speak?' said Gandalf.
#  'What do you?' said Pippin Gandalf. 'For this?'
#  'I won't we

# %%
# Visualize token dot product similarities
similarities = (gpt.embedding_table @ gpt.embedding_table.transpose()).get()


similarities /= np.linalg.trace(similarities)

for i in range(len(similarities)):
  similarities[i, i] = 0

sns.heatmap(similarities, cmap = "viridis")
plt.show()

# %%
path = "/content/drive/MyDrive/ai-models/"

# %%
def save_weights(model, path):

  lst = []

  for layer in model.layers:

    dct = {
        "name": type(layer).__name__,
        "parameters": []
    }

    for parameter in layer.parameters:
      dct["parameters"].append(parameter.get())
    lst.append(dct)

  with open(path, "wb") as handle:
    pickle.dump(lst, handle)


def load_weights(model, path):

  model._zero_grad()

  lst = []

  with open(path, "rb") as handle:
    lst = pickle.load(handle)

  for layer, dct in zip(model.layers, lst):
    for parameter, arr in zip(layer.parameters, dct["parameters"]):
      parameter *= 0
      parameter += xp.array(arr, dtype = xp.float32)

# %%
save_weights(gpt.model, path + "my_lotr_gpt_512.pkl")

# %%
load_weights(gpt.model, path + "my_lotr_gpt_1024.pkl")

# %% [markdown]
# ### Naive/Unoptimized Pytorch DenseNet Comparison

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchsummary
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from tqdm import tqdm

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
trainsform = transforms.Compose(
    [
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding = 4),
        transforms.RandomRotation(15),
        transforms.ToTensor()
    ]
)

testsform = transforms.Compose(
    [
        transforms.ToTensor()
    ])

batch_size = 256

trainset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/datasets', train=True,
                                        download=True, transform=trainsform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True)

testset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/datasets', train=False,
                                       download=True, transform=testsform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
class DenseLayer(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, growth_rate, 3, padding = 1),
        )


    def forward(self, x):
        return torch.concat((x, self.fn(x)), dim = 1)

class DenseBlock(nn.Module):
    def __init__(self, in_channels, growth_rate, num_layers):
        super().__init__()
        self.layers = nn.Sequential(*[
            DenseLayer(in_channels + (i * growth_rate), growth_rate) for i in range(num_layers)
        ])
    def forward(self, x):
        return self.layers(x)

class TransitionBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, out_channels, 1),
            nn.AvgPool2d(2,2)
        )
    def forward(self, x):
        return self.fn(x)


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding = 1),
            DenseBlock(32, 16, 6),
            TransitionBlock(128, 64),
            DenseBlock(64, 16, 6),
            TransitionBlock(160, 80),
            DenseBlock(80, 16, 6),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(176, 10),
        )

    def forward(self, x):
        return self.net(x)

net = Net()
net.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001)

# %%
for epoch in range(20):  # loop over the dataset multiple times

    net.train()
    running_loss = 0.0

    for i, data in tqdm(enumerate(trainloader, 0), total = len(trainloader)):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()

    print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / len(trainloader)}')


    net.eval()
    correct = 0

    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for i, data in tqdm(enumerate(testloader, 0), total = len(testloader)):

            images, labels = data

            images = images.to(device)
            labels = labels.to(device)

            # calculate outputs by running images through the network
            outputs = net(images)

            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs, 1)

            correct += (predicted == labels).sum().item()

    print(f'Test Accuracy: {100 * correct // len(testset)} %')
# Out:
# 100%|██████████| 196/196 [00:26<00:00,  7.50it/s]
# [1,   196] loss: 1.6551714399639441
# 100%|██████████| 40/40 [00:01<00:00, 21.41it/s]
# Test Accuracy: 42 %
# 100%|██████████| 196/196 [00:24<00:00,  7.95it/s]
# [2,   196] loss: 1.3240523472124217
# 100%|██████████| 40/40 [00:01<00:00, 23.36it/s]
# Test Accuracy: 52 %
# 100%|██████████| 196/196 [00:24<00:00,  8.03it/s]
# [3,   196] loss: 1.1502726899117839
# 100%|██████████| 40/40 [00:01<00:00, 23.33it/s]
# Test Accuracy: 61 %
# 100%|██████████| 196/196 [00:24<00:00,  7.96it/s]
# [4,   196] loss: 1.0588929251748689
# 100%|██████████| 40/40 [00:01<00:00, 23.16it/s]
# Test Accuracy: 61 %
# 100%|██████████| 196/196 [00:24<00:00,  8.01it/s]
# [5,   196] loss: 0.9870564435817757
# 100%|██████████| 40/40 [00:01<00:00, 23.76it/s]
# Test Accuracy: 63 %
# 100%|██████████| 196/196 [00:24<00:00,  8.09it/s]
# [6,   196] loss: 0.9257143629448754
# 100%|██████████| 40/40 [00:01<00:00, 23.42it/s]
# Test Accuracy: 66 %
# 100%|██████████| 196/196 [00:24<00:00,  8.06it/s]
# [7,   196] loss: 0.8836886949685155
# 100%|██████████| 40/40 [00:01<00:00, 23.68it/s]
# Test Accuracy: 65 %
# 100%|██████████| 196/196 [00:24<00:00,  8.04it/s]
)

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=4, persistent_workers = True,
                                          pin_memory=True)

testset = torchvision.datasets.CIFAR10(root='/content/drive/MyDrive/datasets', train=False,
                                       download=True, transform=testsform)

testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=4, persistent_workers = True,
                                         pin_memory=True)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
class DenseLayer(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, growth_rate, 3, padding = 1, bias = False),
        )
    def forward(self, x):
        return torch.concat((x, self.fn(x)), dim = 1)

class DenseBlock(nn.Module):
    def __init__(self, in_channels, growth_rate, num_layers):
        super().__init__()
        self.layers = nn.Sequential(*[
            DenseLayer(in_channels + (i * growth_rate), growth_rate) for i in range(num_layers)
        ])
    def forward(self, x):
        return self.layers(x)

class TransitionBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.fn = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.SiLU(),
            nn.Dropout(0.25),
            nn.Conv2d(in_channels, out_channels, 1, bias = False),
            nn.AvgPool2d(2,2)
        )
    def forward(self, x):
        return self.fn(x)


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, 32, 3, padding = 1, bias = False),
            DenseBlock(32, 16, 6),
            TransitionBlock(128, 64),
            DenseBlock(64, 16, 6),
            TransitionBlock(160, 80),
            DenseBlock(80, 16, 6),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(176, 10),
        )

    def forward(self, x):
        return self.net(x)

net = Net()
net = net.to(device, memory_format=torch.channels_last)
net = torch.compile(net)

criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(net.parameters(), lr=0.001, fused=True)

# %%
for epoch in range(20):  # loop over the dataset multiple times

    net.train()
    running_loss = torch.tensor(0.0, device = device)

    for i, data in tqdm(enumerate(trainloader, 0), total = len(trainloader)):

        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        inputs = inputs.to(device, memory_format = torch.channels_last, non_blocking=True)
        labels = labels.to(device, non_blocking=True)

        # zero the parameter gradients
        optimizer.zero_grad(set_to_none=True)

        # forward + backward + optimize
        with torch.autocast(device_type = "cuda", dtype = torch.bfloat16):
            outputs = net(inputs)
            loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.detach()

    print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss.item() / len(trainloader)}')


    net.eval()
    correct = torch.tensor(0, device = device)

    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for i, data in tqdm(enumerate(testloader, 0), total = len(testloader)):

            images, labels = data
            images = images.to(device, memory_format = torch.channels_last, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            # calculate outputs by running images through the network
            with torch.autocast(device_type = "cuda", dtype = torch.bfloat16):
                outputs = net(images)

            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs, 1)

            correct += (predicted == labels).sum()

    print(f'Test Accuracy: {100 * correct.item() // len(testset)} %')
# Out:
# 100%|██████████| 196/196 [02:28<00:00,  1.32it/s]
# [1,   196] loss: 1.6353510642538265
# 100%|██████████| 40/40 [00:32<00:00,  1.25it/s]
# Test Accuracy: 46 %
# 100%|██████████| 196/196 [00:05<00:00, 38.04it/s]
# [2,   196] loss: 1.2796106143873565
# 100%|██████████| 40/40 [00:00<00:00, 79.81it/s]
# Test Accuracy: 52 %
# 100%|██████████| 196/196 [00:05<00:00, 37.83it/s]
# [3,   196] loss: 1.1114455242546237
# 100%|██████████| 40/40 [00:00<00:00, 81.49it/s]
# Test Accuracy: 56 %
# 100%|██████████| 196/196 [00:05<00:00, 38.58it/s]
# [4,   196] loss: 1.0188953633211097
# 100%|██████████| 40/40 [00:00<00:00, 85.17it/s]
# Test Accuracy: 64 %
# 100%|██████████| 196/196 [00:05<00:00, 37.45it/s]
# [5,   196] loss: 0.9551509935028699
# 100%|██████████| 40/40 [00:00<00:00, 87.45it/s]
